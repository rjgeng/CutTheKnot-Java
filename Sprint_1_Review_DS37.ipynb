# %% [markdown]
# <a href="https://colab.research.google.com/github/rjgeng/CutTheKnot-Java/blob/master/Sprint_1_Review_DS37.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
weather = pd.read_csv('./drive/MyDrive/LSTM-Multivariate_pollution.csv')
weather.head()
# Out:
#                   date  pollution  dew  temp  ...  wnd_dir wnd_spd  snow  rain
# 0  2010-01-02 00:00:00      129.0  -16  -4.0  ...       SE    1.79     0     0
# 1  2010-01-02 01:00:00      148.0  -15  -4.0  ...       SE    2.68     0     0
# 2  2010-01-02 02:00:00      159.0  -11  -5.0  ...       SE    3.57     0     0
# 3  2010-01-02 03:00:00      181.0   -7  -5.0  ...       SE    5.36     1     0
# 4  2010-01-02 04:00:00      138.0   -7  -5.0  ...       SE    6.25     2     0
#
# [5 rows x 9 columns]

# %%
pollution = pd.read_csv('./drive/MyDrive/pollution_test_data1.csv')
pollution.head()
# Out:
#    dew  temp  press wnd_dir  wnd_spd  snow  rain  pollution
# 0  -16     4   1027      SE     3.58     0     0        128
# 1  -17     5   1027      SE     7.60     0     0         77
# 2  -16     4   1027      SE     9.39     0     0         65
# 3  -16     1   1028      cv     0.89     0     0         79
# 4  -14     0   1028      NE     1.79     0     0         93

# %%
weather.shape
# Out:
# (43800, 9)

# %%
pollution.shape
# Out:
# (346, 8)

# %%
merge_practice = pd.merge(pollution, weather, on ='pollution', how = 'left')
merge_practice
# Out:
#         dew_x  temp_x  press_x wnd_dir_x  ...  wnd_dir_y  wnd_spd_y  snow_y  rain_y
# 0         -16       4     1027        SE  ...         cv       1.78       0       0
# 1         -16       4     1027        SE  ...         NE       0.89       0       0
# 2         -16       4     1027        SE  ...         cv       0.89       5       0
# 3         -16       4     1027        SE  ...         SE       1.79       0       0
# 4         -16       4     1027        SE  ...         NW      67.48       0       0
# ...       ...     ...      ...       ...  ...        ...        ...     ...     ...
# 106573    -21      -3     1034        NW  ...         NW       4.92       0       0
# 106574    -21      -3     1034        NW  ...         NW      25.03       0       0
# 106575    -21      -3     1034        NW  ...         NW      45.14       0       0
# 106576    -21      -3     1034        NW  ...         NW     170.29       0       0
# ...

# %%
pd.concat([weather, pollution])
# Out:
#                     date  pollution  dew  temp  ...  wnd_dir wnd_spd  snow  rain
# 0    2010-01-02 00:00:00      129.0  -16  -4.0  ...       SE    1.79     0     0
# 1    2010-01-02 01:00:00      148.0  -15  -4.0  ...       SE    2.68     0     0
# 2    2010-01-02 02:00:00      159.0  -11  -5.0  ...       SE    3.57     0     0
# 3    2010-01-02 03:00:00      181.0   -7  -5.0  ...       SE    5.36     1     0
# 4    2010-01-02 04:00:00      138.0   -7  -5.0  ...       SE    6.25     2     0
# ..                   ...        ...  ...   ...  ...      ...     ...   ...   ...
# 341                  NaN        8.0  -23  -2.0  ...       NW  231.97     0     0
# 342                  NaN       10.0  -22  -3.0  ...       NW  237.78     0     0
# 343                  NaN       10.0  -22  -3.0  ...       NW  242.70     0     0
# 344                  NaN        8.0  -22  -4.0  ...       NW  246.72     0     0
# 345                  NaN       12.0  -21  -3.0  ...       NW  249.85     0     0
#
# ...

# %%
weather
# Out:
#                       date  pollution  dew  temp  ...  wnd_dir wnd_spd  snow  rain
# 0      2010-01-02 00:00:00      129.0  -16  -4.0  ...       SE    1.79     0     0
# 1      2010-01-02 01:00:00      148.0  -15  -4.0  ...       SE    2.68     0     0
# 2      2010-01-02 02:00:00      159.0  -11  -5.0  ...       SE    3.57     0     0
# 3      2010-01-02 03:00:00      181.0   -7  -5.0  ...       SE    5.36     1     0
# 4      2010-01-02 04:00:00      138.0   -7  -5.0  ...       SE    6.25     2     0
# ...                    ...        ...  ...   ...  ...      ...     ...   ...   ...
# 43795  2014-12-31 19:00:00        8.0  -23  -2.0  ...       NW  231.97     0     0
# 43796  2014-12-31 20:00:00       10.0  -22  -3.0  ...       NW  237.78     0     0
# 43797  2014-12-31 21:00:00       10.0  -22  -3.0  ...       NW  242.70     0     0
# 43798  2014-12-31 22:00:00        8.0  -22  -4.0  ...       NW  246.72     0     0
# ...

# %%
weather.describe()
# Out:
#           pollution           dew  ...          snow          rain
# count  43800.000000  43800.000000  ...  43800.000000  43800.000000
# mean      94.013516      1.828516  ...      0.052763      0.195023
# std       92.252276     14.429326  ...      0.760582      1.416247
# min        0.000000    -40.000000  ...      0.000000      0.000000
# 25%       24.000000    -10.000000  ...      0.000000      0.000000
# 50%       68.000000      2.000000  ...      0.000000      0.000000
# 75%      132.250000     15.000000  ...      0.000000      0.000000
# max      994.000000     28.000000  ...     27.000000     36.000000
#
# [8 rows x 7 columns]

# %%
weather.describe()
# Out:
#           pollution           dew  ...          snow          rain
# count  43800.000000  43800.000000  ...  43800.000000  43800.000000
# mean      94.013516      1.828516  ...      0.052763      0.195023
# std       92.252276     14.429326  ...      0.760582      1.416247
# min        0.000000    -40.000000  ...      0.000000      0.000000
# 25%       24.000000    -10.000000  ...      0.000000      0.000000
# 50%       68.000000      2.000000  ...      0.000000      0.000000
# 75%      132.250000     15.000000  ...      0.000000      0.000000
# max      994.000000     28.000000  ...     27.000000     36.000000
#
# [8 rows x 7 columns]

# %%
weather.select_dtypes('number')
# Out:
#        pollution  dew  temp   press  wnd_spd  snow  rain
# 0          129.0  -16  -4.0  1020.0     1.79     0     0
# 1          148.0  -15  -4.0  1020.0     2.68     0     0
# 2          159.0  -11  -5.0  1021.0     3.57     0     0
# 3          181.0   -7  -5.0  1022.0     5.36     1     0
# 4          138.0   -7  -5.0  1022.0     6.25     2     0
# ...          ...  ...   ...     ...      ...   ...   ...
# 43795        8.0  -23  -2.0  1034.0   231.97     0     0
# 43796       10.0  -22  -3.0  1034.0   237.78     0     0
# 43797       10.0  -22  -3.0  1034.0   242.70     0     0
# 43798        8.0  -22  -4.0  1034.0   246.72     0     0
# 43799       12.0  -21  -3.0  1034.0   249.85     0     0
#
# [43800 rows x 7 columns]

# %%
weather.dtypes
# Out:
# date          object
# pollution    float64
# dew            int64
# temp         float64
# press        float64
# wnd_dir       object
# wnd_spd      float64
# snow           int64
# rain           int64
# dtype: object

# %%
weather['date'] = pd.to_datetime(weather['date'])

# %%
weather.dtypes
# Out:
# date         datetime64[ns]
# pollution           float64
# dew                   int64
# temp                float64
# press               float64
# wnd_dir              object
# wnd_spd             float64
# snow                  int64
# rain                  int64
# dtype: object

# %%
weather['date'].dt.hour
# Out:
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
#          ..
# 43795    19
# 43796    20
# 43797    21
# 43798    22
# 43799    23
# Name: date, Length: 43800, dtype: int64

# %%
sns.pairplot(weather)

# %%
weather.describe(exclude= 'number')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
#                        date wnd_dir
# count                 43800   43800
# unique                43800       4
# top     2010-01-02 00:00:00      SE
# freq                      1   15290
# first   2010-01-02 00:00:00     NaN
# last    2014-12-31 23:00:00     NaN

# %%
weather['wnd_dir'].value_counts()
# Out:
# SE    15290
# NW    14130
# cv     9384
# NE     4996
# Name: wnd_dir, dtype: int64

# %%
weather['wnd_dir'].value_counts().plot(kind= 'bar')

# %%
weather.groupby('wnd_dir')['pollution'].mean().plot(kind='bar')

# %%
weather['pollution'].mean()
# Out:
# 94.01351598173515

# %%
weather.groupby('wnd_dir')['pollution'].sum()
# Out:
# wnd_dir
# NE     428885.0
# NW     945601.0
# SE    1615003.0
# cv    1128303.0
# Name: pollution, dtype: float64

# %%
weather.loc[1, 'dew']
# Out:
# -15

# %%
weather.loc[1, 'dew'] = -20
weather.head()
# Out:
#                  date  pollution  dew  temp  ...  wnd_dir wnd_spd  snow  rain
# 0 2010-01-02 00:00:00      129.0  -16  -4.0  ...       SE    1.79     0     0
# 1 2010-01-02 01:00:00      148.0  -20  -4.0  ...       SE    2.68     0     0
# 2 2010-01-02 02:00:00      159.0  -11  -5.0  ...       SE    3.57     0     0
# 3 2010-01-02 03:00:00      181.0   -7  -5.0  ...       SE    5.36     1     0
# 4 2010-01-02 04:00:00      138.0   -7  -5.0  ...       SE    6.25     2     0
#
# [5 rows x 9 columns]

# %%
weather.loc[weather['wnd_spd'] > 4]
# Out:
#                      date  pollution  dew  temp  ...  wnd_dir wnd_spd  snow  rain
# 3     2010-01-02 03:00:00      181.0   -7  -5.0  ...       SE    5.36     1     0
# 4     2010-01-02 04:00:00      138.0   -7  -5.0  ...       SE    6.25     2     0
# 5     2010-01-02 05:00:00      109.0   -7  -6.0  ...       SE    7.14     3     0
# 6     2010-01-02 06:00:00      105.0   -7  -6.0  ...       SE    8.93     4     0
# 7     2010-01-02 07:00:00      124.0   -7  -5.0  ...       SE   10.72     0     0
# ...                   ...        ...  ...   ...  ...      ...     ...   ...   ...
# 43795 2014-12-31 19:00:00        8.0  -23  -2.0  ...       NW  231.97     0     0
# 43796 2014-12-31 20:00:00       10.0  -22  -3.0  ...       NW  237.78     0     0
# 43797 2014-12-31 21:00:00       10.0  -22  -3.0  ...       NW  242.70     0     0
# 43798 2014-12-31 22:00:00        8.0  -22  -4.0  ...       NW  246.72     0     0
# ...

# %%
weather.loc[weather['wnd_spd'] > 4, "Wind Factor"] = "Windy"
weather.loc[weather['wnd_spd'] <= 4, "Wind Factor"] = "Not Windy"
weather.head()
# Out:
#                  date  pollution  dew  temp  ...  wnd_spd snow  rain  Wind Factor
# 0 2010-01-02 00:00:00      129.0  -16  -4.0  ...     1.79    0     0    Not Windy
# 1 2010-01-02 01:00:00      148.0  -20  -4.0  ...     2.68    0     0    Not Windy
# 2 2010-01-02 02:00:00      159.0  -11  -5.0  ...     3.57    0     0    Not Windy
# 3 2010-01-02 03:00:00      181.0   -7  -5.0  ...     5.36    1     0        Windy
# 4 2010-01-02 04:00:00      138.0   -7  -5.0  ...     6.25    2     0        Windy
#
# [5 rows x 10 columns]

# %%
weather.loc[weather['wnd_spd'] <= 4, 'dew'] = 'These are numbers'
weather.head()
# Out:
#                  date  pollution                dew  ...  snow  rain Wind Factor
# 0 2010-01-02 00:00:00      129.0  These are numbers  ...     0     0   Not Windy
# 1 2010-01-02 01:00:00      148.0  These are numbers  ...     0     0   Not Windy
# 2 2010-01-02 02:00:00      159.0  These are numbers  ...     0     0   Not Windy
# 3 2010-01-02 03:00:00      181.0                 -7  ...     1     0       Windy
# 4 2010-01-02 04:00:00      138.0                 -7  ...     2     0       Windy
#
# [5 rows x 10 columns]

# %%
weather = pd.read_csv('./drive/MyDrive/LSTM-Multivariate_pollution.csv')
weather.head()
# Out:
#                   date  pollution  dew  temp  ...  wnd_dir wnd_spd  snow  rain
# 0  2010-01-02 00:00:00      129.0  -16  -4.0  ...       SE    1.79     0     0
# 1  2010-01-02 01:00:00      148.0  -15  -4.0  ...       SE    2.68     0     0
# 2  2010-01-02 02:00:00      159.0  -11  -5.0  ...       SE    3.57     0     0
# 3  2010-01-02 03:00:00      181.0   -7  -5.0  ...       SE    5.36     1     0
# 4  2010-01-02 04:00:00      138.0   -7  -5.0  ...       SE    6.25     2     0
#
# [5 rows x 9 columns]

# %%
weather.loc[weather['wnd_spd'] > 4, "Wind Factor"] = "Windy"
weather.loc[weather['wnd_spd'] <= 4, "Wind Factor"] = "Not Windy"

# %%
weather.loc[(weather['pollution'] > 100) & (weather['Wind Factor'] == 'Windy')]
# Out:
#                       date  pollution  dew  ...  snow  rain Wind Factor
# 3      2010-01-02 03:00:00      181.0   -7  ...     1     0       Windy
# 4      2010-01-02 04:00:00      138.0   -7  ...     2     0       Windy
# 5      2010-01-02 05:00:00      109.0   -7  ...     3     0       Windy
# 6      2010-01-02 06:00:00      105.0   -7  ...     4     0       Windy
# 7      2010-01-02 07:00:00      124.0   -7  ...     0     0       Windy
# ...                    ...        ...  ...  ...   ...   ...         ...
# 43730  2014-12-29 02:00:00      373.0  -11  ...     0     0       Windy
# 43731  2014-12-29 03:00:00      372.0  -11  ...     0     0       Windy
# 43732  2014-12-29 04:00:00      318.0  -12  ...     0     0       Windy
# 43733  2014-12-29 05:00:00      188.0  -12  ...     0     0       Windy
# 43735  2014-12-29 07:00:00      136.0  -12  ...     0     0       Windy
#
# [6574 rows x 10 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection  import train_test_split

# %%
X = weather.select_dtypes('number').drop(columns = 'pollution')
y = weather['pollution']

# %%
lr = LinearRegression()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .3)

# %%
lr.fit(X_train, y_train)

print(lr.score(X_train, y_train))
print(lr.score(X_test, y_test))
# Out:
# 0.20978097272336227
# 0.2248328353546617

# %%
lr.predict(X_test)
# Out:
# array([ 82.19051169, 136.78858773,  99.67411548, ...,  17.16415865,
#         47.63428477, 107.27721659])

# %%
X_test
# Out:
#        dew  temp   press  wnd_spd  snow  rain
# 26345  -23  -8.0  1041.0     0.89     0     0
# 15362    5   7.0  1022.0     0.89     0     0
# 13652   24  24.0  1000.0     3.13     0     7
# 893     -6  -4.0  1019.0     1.79     0     0
# 17377  -11  -7.0  1034.0     1.79     0     0
# ...    ...   ...     ...      ...   ...   ...
# 28159   -3  -2.0  1025.0     7.60     0     0
# 11863   14  15.0  1007.0     0.89     0     0
# 2460   -17  11.0  1027.0     1.79     0     0
# 34091  -10  10.0  1025.0    28.17     0     0
# 29776   16  23.0  1007.0    16.09     0     0
#
# [13140 rows x 6 columns]
